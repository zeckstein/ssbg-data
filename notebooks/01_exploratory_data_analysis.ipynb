# %% [markdown]
# # SSBG Data Analysis - Exploratory Data Analysis
#
# This notebook provides a template for exploring SSBG data.
#
# ## Setup

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Import custom helper functions
import sys
sys.path.append('../')

from src.data_loader import load_csv, load_excel, get_data_path
from src.cleaning import (
    remove_duplicates, 
    handle_missing_values, 
    standardize_column_names
)
from src.analysis import (
    get_summary_statistics, 
    calculate_correlation, 
    find_missing_data
)

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Load Data
#
# Load your SSBG data from the `data/raw` folder.

# %%
# Example: Load CSV data
# df = load_csv(get_data_path('your_data_file.csv', data_type='raw'))

# Example: Load Excel data
# df = load_excel(get_data_path('your_data_file.xlsx', data_type='raw'))

# Display first few rows
# df.head()

# %% [markdown]
# ## 2. Data Cleaning
#
# Clean the data using helper functions.

# %%
# Standardize column names
# df = standardize_column_names(df)

# Remove duplicates
# df = remove_duplicates(df)

# Handle missing values
# df = handle_missing_values(df, strategy='drop')

# Display cleaned data info
# df.info()

# %% [markdown]
# ## 3. Exploratory Data Analysis
#
# Explore the data to understand its structure and patterns.

# %%
# Check for missing data
# missing_data = find_missing_data(df)
# print(missing_data)

# %%
# Get summary statistics
# summary_stats = get_summary_statistics(df)
# print(summary_stats)

# %%
# Calculate correlations
# correlations = calculate_correlation(df)
# print(correlations)

# %% [markdown]
# ## 4. Visualizations
#
# Create visualizations to understand the data better.

# %%
# Example: Distribution plot
# plt.figure(figsize=(10, 6))
# sns.histplot(data=df, x='column_name', bins=30)
# plt.title('Distribution of Column Name')
# plt.xlabel('Column Name')
# plt.ylabel('Frequency')
# plt.show()

# %%
# Example: Correlation heatmap
# plt.figure(figsize=(12, 8))
# sns.heatmap(correlations, annot=True, cmap='coolwarm', center=0)
# plt.title('Correlation Heatmap')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 5. Save Processed Data
#
# Save the cleaned and processed data for future use.

# %%
# from src.data_loader import save_csv

# Save processed data
# save_csv(df, get_data_path('processed_data.csv', data_type='processed'))
# print('Data saved successfully!')
